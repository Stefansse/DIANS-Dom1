# %%
pip install geopy

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Dizajn i arhitektura/excel data za dizjan.xlsx')

# %%
df
# Out:
#    Регистар на винарски визби во Р. Македонија Unnamed: 1 Unnamed: 2  \
# 0                                        Место        Бр.        Бр.
# 1                                       Битола          1          1
# 2                                     Богданци          2          1
# 3                                    Валандово          3          1
# 4                                        Велес          4          1
# ..                                         ...        ...        ...
# 74                                         NaN         71          3
# 75                                         NaN         72          4
# 76                                         NaN         73          5
# 77                                         NaN         74          6
# 78                                         NaN        NaN        NaN
#
#                                           Unnamed: 3  \
# 0                                   Регистарски број
# ...

# %%
columns_to_keep = [0, 3, 5]
df = df.iloc[:, columns_to_keep]

# %%
df
# Out:
#    Регистар на винарски визби во Р. Македонија  \
# 0                                        Место
# 1                                       Битола
# 2                                     Богданци
# 3                                    Валандово
# 4                                        Велес
# ..                                         ...
# 74                                         NaN
# 75                                         NaN
# 76                                         NaN
# 77                                         NaN
# 78                                         NaN
#
#                                           Unnamed: 3  \
# 0                                   Регистарски број
# 1                                  Уп I бр.29-753/15
# 2                                         29-12114/3
# 3                   29-5547/2\n29-16049/3\n16-930/17
# 4                                          08-5885/2
# ..                                               ...
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Load your Excel data into a DataFrame



# Initialize a geolocator (using Nominatim - OpenStreetMap)
geolocator = Nominatim(user_agent="your_app_name")

# Function to get location data for each address
def get_location(address):
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# Apply the function to the 'Address' column and create new 'Latitude' and 'Longitude' columns
df['Coordinates'] = df['Регистар на винарски визби во Р. Македонија'].apply(get_location)

# Split the 'Coordinates' column into 'Latitude' and 'Longitude' columns
df[['Latitude', 'Longitude']] = pd.DataFrame(df['Coordinates'].tolist(), index=df.index)

# Save the DataFrame with location data to a new Excel file
output_excel_path = 'output_with_location.xlsx'
df.to_excel(output_excel_path, index=False)

print(f'Location data added and saved at {output_excel_path}')
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=nan&format=json&limit=1
# Location data added and saved at output_with_location.xlsx
# <ipython-input-18-ca6b5d51af70>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coordinates'] = df['Регистар на винарски визби во Р. Македонија'].apply(get_location)
# <ipython-input-18-ca6b5d51af70>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
